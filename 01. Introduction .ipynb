# %% [raw]
# How to run cell?
#
# 1. Control + enter >> Current cell is going to run
# 2. Run Button at top menu bar
# 3. Shift + enter >> Current cell runs and create new one cell.

# %% [raw]
# What is Data Science & Machine Learning?
#     Data Science is interdisciplinary field thats scientific methods, processes, algorithms and system to extract knowledge and insights from noisy, unstructured data and apply the actionable insights.
#
#    Machine learning is a subset of AI that enables a machine to automatically learn from data, improve performance from past experience, and predict things without being explicitly programmed.

# %% [markdown]
# # Python

# %% [raw]
# Python language was invented in 1991 by Guido Van Russom.
# First version was 0.9.0, Current version is 3.11.0 as of today.
# Big brands including NASA, Google, Facebook they use python.

# %% [markdown]
# ## Features of Python

# %% [raw]
# 1. Simple to learn, Understand & Comprehend. Simple to debug.
# 2. Free & Open Source/available for all.
# 3. It has very vast library base.
# 4. It is friendly to use. user friendly.
# 5. It supports bot procedural & Object oriented programming Language.
# 6. Python is interpreted language.
# 7. Dynamically typed language. (We need not mention the data type of the variable. don't need of variable data type declaration

# %% [markdown]
# ![ai.png](attachment:ai.png)

# %% [raw]
# RoadMap for Data Science
#
# 1. Python (Data Types, loops, conditional statments, function, OOPS, File operations, regular exp, date time)
# 2. Basics of SQL & NoSQL.
# 3. Tools, library (Numpy, Pandas)
# 4. Machine Learning Algo (stats,maths, Matplot lib, seaborn, scikit, nltk)
#     - Supervised
#     - Unsupervised
#     - Reinforcement
# 5. Flask (API)
# 6. Github
# 7. Project deployment on AWS.
# 8. End to end Projects
